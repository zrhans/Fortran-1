# %% [markdown]
# # Movimento Retilineo Uniformemente Variado (MRUV)
#
# É o movimento no qual a velocidade varia em relação ao tempo de modo uniforme, ou seja, possui uma aceleração não nula e constante. Por exemplo, se temos uma aceleração de$$ a(t) = 50 m/s^2 $$para qualquer valor de t, a velocidade é a mesma $50 m/s$.
#
# Integrando essa equação duas vezes obtemos:
# $$ \begin{equation*}a = 50 m/s^2\end{equation*} $$
# $$ \begin{equation*}v(t) = v_0 + (50 m/s^2) t = v_0 + a t \end{equation*} $$
# $$ \begin{equation*}s(t) = s_0 + v_0t + (50 m/s^2) t^2/2 = s_0 + v_0t + a t^2/2 \end{equation*} $$
#
# Na segunda equação podemos utilizar somente valores de velocidades, enquanto que na terceira podemos utilizar valores de posições e velocidades para realizar cálculos.
#
# Conhecer essas equações consiste em, a partir de uma aceleração não nula $a (m/s^2)$, ser capaz de calcular posições, velocidades e tempos iniciais e finais.

# %% [markdown]
# [Leitura adicional](https://webfisica.com/laravel/public/fisica/curso-de-fisica-basica/aula/1-5)

# %% [markdown]
# __Exercício 1 :__
#
# Um carro que trafegava a __108 km/h__ ficou sem freio em uma rua horizontal. O motorista percebeu e resolveu parar o veículo. Sabendo que ele levou __30 segundos__ para parar totalmente utilizando apenas o freio de mão:
#
# * (1) Implemente a equação da __velocidade__ e calcule a __desaceleração__ proporcionada pelo freio de mão.
# * (2) Implemente a equação da __posição__ e calcule a __distância percorrida__ até parar.
#
# (Dica): Utilize o próprio Fortran para realizar a mudança de km/h para m/s.
#
# * __Desafio:__ Tente gerar um programa que sirva para responder ambas as questões.

# %% [markdown]
# ##### resposta (1)

# %% [raw]
# program mruv
# implicit none
# real:: v0, v1, t, a
#
# write(*,*) "Inserir valores v0(km/h) v1(m/s) t(s) :"
# read(*,*) v0, v1, t
# ! Partindo dessa equação v1 = v0 + a*t
# ! isolamos a para ser calculado.
#
# v0 = v0/3.6
# a = (v1-v0)/t
# write(*,*) " A aceleração é a =", a, "m/s"
#
# end program

# %% [markdown]
# ##### resposta (2)

# %% [raw]
# program mruv
# implicit none
# real:: s0, s, v0, t, a
#
# write(*,*) "Inserir valores s0(m) v0(km/h) t(s) a(m/s**2):"
# read(*,*) s0, v0, t, a
# v0 = v0/3.6
# s = s0+v0*t+(a*t**2)/2
#
# write(*,*) " o carro percorreu por s =", s, "(m) até parar."
#
# end program

# %% [markdown]
# ##### resposta (desafio)

# %% [raw]
# program mruv
# implicit none
# real:: s0, s, v1, v0, t, a
# Character(len = 5) :: tipo, modo1, modo2, modo3
#
# write(*,*) " Escolha a grandeza a ser calculada: "
# write(*,*) " digite v para equação da velocidade, "
# write(*,*) " Ou digite s para equação da posição "
#
# modo1 = "s"
# modo2 = "v"
# read(*,*) tipo
#
# if (tipo == modo1) then
#         write(*,*) "Inserir valores s0(m) v0(km/h) t(s) a(m/s^2):"
#         read(*,*) s0, v0, t, a
#         v0 = v0/3.6
#         s = s0+v0*t+(a*t**2)/2
#
#         write(*,*) " o carro percorreu por s =", s, "(m) até parar."
#
#
# else if (tipo == modo2) then
#         write(*,*) "Inserir valores v0(km/h) v1(m/s) t(s) :"
#         read(*,*) v0, v1, t
#         ! Partindo dessa equação v1 = v0 + a*t
#         ! isolamos a para ser calculado.
#
#         !v = 0
#         v0 = v0/3.6
#         a = (v1-v0)/t
#
#         write(*,*) " A aceleração é a =", a, "m/s**2"
#
# end if
# end program

# %% [markdown]
# ##### Execução
# ![image.png](attachment:image.png)

# %% [markdown]
# __Exercício 2 :__
#
# Considere um móvel, em movimento retilíneo, partindo do repouso (Vo=0) e tem aceleração constante de 2 m/s².
# $$\begin{equation}x(t) = x_0 + v_0t+\frac{at^2}{2} \end{equation}
# $$
# * Utilizando a equação acima, faça um programa em Fortran para calcular a posição do móvel a cada instante de tempo entre 0 e 10 segundos.
#
# Precisa iterar (variar o valor de $t$ 10 vezes), imprimindo na tela o valor da posição x(t) na tela a cada iteração.

# %% [raw]
# program mruv
# implicit None ! isso nos obrig a declarar todas as variáveis que usaremos
#
# real :: x0=0, x=0, v0=0, a=2
# integer :: i, t
#
# do t = 1,10
#     x = x0+vo*t+0.5*a*t**2
#     print*, t, x
# end __doc__
#
# end program mruv

# %% [markdown]
# #### Desafio 1
#
# Implemente um algoritmo dando maior interatividade com o usuário e a resolução do domínio sendo pertencente aos números reais [dt=0.01] ao invés de dt=1

# %% [markdown]
# #### Desafio 2
#
# Altere o Programa para o cálculo de um movimento (bidimensional) ou Oblíquo (fornecendo dados iniciais adequados), gere os resultados em um arquivo externo e construa um gráfico da posição instantânea do móvel.
